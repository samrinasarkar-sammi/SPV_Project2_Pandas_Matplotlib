# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %matplotlib inline

# %%
#loading and importing the data

df = pd.read_csv('football-players-drop-duplicates.csv')
df
# Out:
#                  Name Nationality  Jersey Number  Total Performance  \
# 0            l. messi   Argentina             10                 94
# 1   cristiano ronaldo    Portugal              7                 94
# 2           neymar jr      Brazil             10                 92
# 3              de gea       Spain              1                 91
# 4        k. de bruyne     Belgium              7                 91
# 5           e. hazard     Belgium             10                 91
# 6           l. modri?     Croatia             10                 91
# 7            n. kanté      France             13                 89
# 8        sergio ramos       Spain             15                 91
# 9            j. oblak    Slovenia              1                 90
# 10    sergio busquets       Spain              5                 89
# 11          p. dybala   Argentina             21                 89
# 12            h. kane     England              9                 89
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.dtypes
# Out:
# Name                               object
# Nationality                        object
# Jersey Number                       int64
# Total Performance                   int64
# Height (inch)                       int64
# Market Place Value in Million       int64
# Age                                 int64
# Skill Moves                         int64
# Total penalties of their career     int64
# dtype: object

# %%
# Line grapph

df['Market Place Value in Million'].plot()

plt.title('Info of data')
plt.xlabel('X axis')
plt.ylabel('VAlue in Million')

plt.savefig('Figures/Info of Value.png')

# %%
x = df['Skill Moves']
y = df['Total Performance']

fig,ax = plt.subplots(figsize=(5,4))

ax.hist(x, color = 'g')


plt.title('Total Performance Over skill moves')
plt.xlabel('Skill Moves')
plt.ylabel('Total Performance')
plt.show()

plt.savefig('Figures/Total Performance Over skill moves.png')

# %%
df.plot(x = 'Age', 
        y = 'Skill Moves', 
        kind = 'bar', 
        color = 'pink',
        title = 'Skill Moves over Age vartically')
plt.savefig('Figures/Skill Moves over Age vartically.png')

# %%
df.plot(x = 'Age', 
        y = 'Skill Moves', 
        kind = 'barh', 
        color = 'm',
        title = 'Skill Moves over Age Horizontally')
plt.savefig('Figures/Skill Moves over Age Horizontally.png')

# %%
# scatter plot
df.plot(x = 'Total Performance', 
        y = 'Market Place Value in Million', 
        kind = 'scatter', 
        color = 'g',
        title = 'Performance based Makret place value for players')
plt.savefig('Figures/Performance based Makret place value for players.png')

# %%
# see different styles
plt.style.available
# Out:
# ['bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark-palette',
#  'seaborn-dark',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'seaborn',
#  'Solarize_Light2',
#  'tableau-colorblind10',
#  '_classic_test']

# %%
plt.style.use('ggplot')

x = df['Total Performance']
y = df['Market Place Value in Million']

fig,ax = plt.subplots(figsize=(5,4))
ax.hist(x)


plt.title('Price value for Performance')
plt.xlabel('Total Performance')
plt.ylabel('Market Place Value in Million')
plt.show()

plt.savefig('Figures/Price value for Performance.png')

# %%
plt.style.use('classic')
df.plot(x = 'Age', 
        y = 'Total Performance', 
        kind = 'bar', 
        color = 'pink',
        title = 'Total Performance by Age')
plt.savefig('Figures/Total Performance by Age.png')

# %%
# scatter plot
plt.style.use('fivethirtyeight')
df.plot(x = 'Total Performance', 
        y = 'Market Place Value in Million', 
        kind = 'scatter', 
        color = 'g',
        title = 'Performance based Makret value for players')
plt.savefig('Figures/Performance based Makret value for players.png')
